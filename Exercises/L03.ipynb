# %%
import pandas as pd
import numpy as np

Auto = pd.read_csv("../Resources/Auto.data", delim_whitespace=True)
Auto

Test = pd.DataFrame()

#Auto["horsepower"]
#np.unique(Auto['horsepower'])
#Test["Green"]= [1,1,2,2,3,3]
#np.unique([1,1,2,2,3,3])
#Auto['horsepower']
Auto.columns
Auto_re = Auto.set_index("name")
Auto_re.loc[ lambda df: (df['year'] > 80) & (df['mpg'] > 30), ['weight', 'origin'] ]
# Out:
# C:\Users\adamt\AppData\Local\Temp\ipykernel_636\4282914684.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   Auto = pd.read_csv("../Resources/Auto.data", delim_whitespace=True)
#                                    weight  origin
# name
# toyota starlet                     1755.0       3
# plymouth champ                     1875.0       1
# honda civic 1300                   1760.0       3
# subaru                             2065.0       3
# datsun 210 mpg                     1975.0       3
# toyota tercel                      2050.0       3
# mazda glc 4                        1985.0       3
# plymouth horizon 4                 2215.0       1
# ford escort 4w                     2045.0       1
# volkswagen jetta                   2190.0       2
# renault 18i                        2320.0       2
# honda prelude                      2210.0       3
# ...

# %%
from ISLP import load_data 
boston = load_data("Boston")
boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio  lstat  medv
# 0       15.3   4.98  24.0
# 1       17.8   9.14  21.6
# 2       17.8   4.03  34.7
# ...

# %%
Auto_re.loc[lambda df: (df['displacement'] < 300) & (df.index.str.contains('ford')
| df.index.str.contains('datsun')), ['weight', 'origin'] ]
# Out:
#                        weight  origin
# name
# ford maverick          2587.0       1
# datsun pl510           2130.0       3
# datsun pl510           2130.0       3
# ford pinto             2046.0       1
# ford torino 500        3302.0       1
# ford mustang           3139.0       1
# datsun 1200            1613.0       3
# ford pinto runabout    2226.0       1
# ford pinto (sw)        2395.0       1
# datsun 510 (sw)        2288.0       3
# ford maverick          3021.0       1
# datsun 610             2379.0       3
# ford pinto             2310.0       1
# ford maverick          2875.0       1
# datsun b210            1950.0       3
# ford pinto             2451.0       1
# datsun 710             2003.0       3
# ford maverick          3158.0       1
# ford pinto             2639.0       1
# datsun 710             2545.0       3
# ford pinto             2984.0       1
# ford maverick          3012.0       1
# ford granada ghia      3574.0       1
# ...

# %%
rng = np.random.default_rng(2)
A = rng.standard_normal((127, 5))
M = rng.choice([0, 5, 10], p=[0.4,0.2,0.4], size=(127,5))
A += M
D = pd.DataFrame(A, columns=['food',
'bar',
'pickle',
'snack',
'popcorn'])
M[:3]

for col in D.columns:
    template = 'Column "{0}" has {1:.2%} missing values'
    print(template.format(col, np.isnan(D[col]).mean()))


for col in D.columns: 
    template = "Column '{0}' total sum = '{1:.2%}'"
    print(template.format(col, np.sum(D[col].mean())) )
# Out:
# Column "food" has 0.00% missing values
# Column "bar" has 0.00% missing values
# Column "pickle" has 0.00% missing values
# Column "snack" has 0.00% missing values
# Column "popcorn" has 0.00% missing values
# Column 'food' total sum = '491.50%'
# Column 'bar' total sum = '500.66%'
# Column 'pickle' total sum = '459.54%'
# Column 'snack' total sum = '479.88%'
# Column 'popcorn' total sum = '534.50%'

# %%
# Exercise 2.4.3

# 1. Draw five curves on the same plot, each curve represents one method
#   a) bias (squared)
#   b) variance 
#   c) training error
#   d) Bayes (or irreducible) error curves
# 2. x-axies = ammount of flexibility in the method 
# 3. y-axies = the values of each curv

# sid 73

import numpy

# %%
# Exercise 2.4.7
import numpy
obs = np.array([
    [ 0, 3, 0],
    [ 2, 0, 0],
    [ 0, 1, 3],
    [ 0, 1, 2],
    [-1, 0, 1],
    [ 1, 1, 1],
    ])

nd = [ ((o[0]-0)**2 + (o[1]-0)**2 + (o[2]-0)**2)**0.5 for o in obs]
nd
# Out:
# [3.0,
#  2.0,
#  3.1622776601683795,
#  2.23606797749979,
#  1.4142135623730951,
#  1.7320508075688772]

# %%
# Exercise 2.4.8
import pandas as pd

# a) 
college = pd.read_csv("../Resources/College.csv")
college

# b)
college.rename({"Unnamed: 0": "College"}, axis=1, inplace=True)
college.set_index("College", inplace=True)
college.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %%
# c) 
college.describe().map(lambda x: f"{x:.0f}")
# Out:
#         Apps Accept Enroll Top10perc Top25perc F.Undergrad P.Undergrad  \
# count    777    777    777       777       777         777         777
# mean    3002   2019    780        28        56        3700         855
# std     3870   2451    929        18        20        4850        1522
# min       81     72     35         1         9         139           1
# 25%      776    604    242        15        41         992          95
# 50%     1558   1110    434        23        54        1707         353
# 75%     3624   2424    902        35        69        4005         967
# max    48094  26330   6392        96       100       31643       21836
#
#       Outstate Room.Board Books Personal  PhD Terminal S.F.Ratio perc.alumni  \
# count      777        777   777      777  777      777       777         777
# mean     10441       4358   549     1341   73       80        14          23
# std       4023       1097   165      677   16       15         4          12
# ...

# %%
# d) 
pd.plotting.scatter_matrix(college[["Top10perc", "Apps", "Enroll"]]);

# %%
# e)
college.boxplot("Outstate", "Private")
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Private'>

# %%
# f) 
college["Elite"] = pd.cut( college["Top10perc"], [0,89,100], labels=["No","Yes"])
college["Elite"].value_counts()
# Out:
# Elite
# No     770
# Yes      7
# Name: count, dtype: int64

# %%
college.boxplot("Outstate", "Elite")
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Elite'>

# %%
# g) 
college.plot.hist(column=["Grad.Rate","Top10perc","Terminal","PhD"], bins=10, layout=(2,2), subplots=True);

# %%
# Exercise 2.4.9

Auto = pd.read_csv("../Resources/Auto.csv", na_values=["?"])


Auto

Auto['horsepower'].max()

Auto.describe().map(lambda x: f"{x:.2f}") 

#Auto_sliced = Auto.loc[0:11] + Auto.loc[86:]
Auto_sliced = pd.concat( [Auto.loc[0:11], Auto.loc[86:]],  )
Auto_sliced.describe().map(lambda x: f"{x:.2f}")
# Out:
#           mpg cylinders displacement horsepower   weight acceleration    year  \
# count  323.00    323.00       323.00     319.00   323.00       323.00  323.00
# mean    24.38      5.39       188.25     101.40  2937.23        15.67   77.10
# std      7.91      1.66       100.51      36.25   808.75         2.75    3.17
# min     11.00      3.00        68.00      46.00  1649.00         8.00   70.00
# 25%     18.00      4.00       100.50      75.00  2217.00        14.00   75.00
# 50%     23.90      4.00       146.00      91.00  2800.00        15.50   77.00
# 75%     30.60      6.00       254.00     115.50  3522.50        17.25   80.00
# max     46.60      8.00       455.00     230.00  4997.00        24.80   82.00
#
#        origin
# count  323.00
# mean     1.59
# std      0.81
# min      1.00
# 25%      1.00
# 50%      1.00
# 75%      2.00
# max      3.00

# %%
# e)
Auto.plot( x=["acceleration"], y=["weight"] , kind="scatter")
# Out:
# <Axes: xlabel='[acceleration]', ylabel='[weight]'>

# %%
# f)
Auto.plot( x=["mpg"], y=["weight"] , kind="scatter")
# Out:
# <Axes: xlabel='[mpg]', ylabel='[weight]'>

# %%
from ISLP import load_data
boston = load_data("boston")
boston
#boston.to_csv("../Resources/Boston.csv")
boston.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'lstat', 'medv'],
#       dtype='object')

# %%
boston.plot( kind="scatter", x=["age"], y=["crim"]);
boston.plot( kind="scatter", x=["indus"], y=["nox"]);
boston.plot( kind="scatter", x=["lstat"], y=["medv"]);

# %%
[ boston.plot( kind="scatter", x=[pre], y=["crim"]) for pre in boston ];

# %%
boston.sort_values("ptratio", ascending=False, inplace=True) 
boston.head()
# Out:
#         crim    zn  indus  chas    nox     rm   age      dis  rad  tax  \
# 355  0.10659  80.0   1.91     0  0.413  5.936  19.5  10.5857    4  334
# 354  0.04301  80.0   1.91     0  0.413  5.663  21.9  10.5857    4  334
# 137  0.35233   0.0  21.89     0  0.624  6.454  98.4   1.8498    4  437
# 129  0.88125   0.0  21.89     0  0.624  5.637  94.7   1.9799    4  437
# 134  0.97617   0.0  21.89     0  0.624  5.757  98.4   2.3460    4  437
#
#      ptratio  lstat  medv
# 355     22.0   5.57  20.6
# 354     22.0   8.05  18.2
# 137     21.2  14.59  17.1
# 129     21.2  18.34  14.3
# 134     21.2  17.31  15.6

# %%
boston["ptratio"].median()
# Out:
# 19.05

# %%
boston.loc[ boston["rm"] > 8 ].describe().map(lambda x: f"{x:.0f}")
# Out:
#       crim  zn indus chas nox  rm age dis rad  tax ptratio lstat medv
# count   13  13    13   13  13  13  13  13  13   13      13    13   13
# mean     1  14     7    0   1   8  72   3   7  325      16     4   44
# std      1  26     5    0   0   0  25   2   5  111       2     1    8
# min      0   0     3    0   0   8   8   2   2  224      13     2   22
# 25%      0   0     4    0   1   8  70   2   5  264      15     3   42
# 50%      1   0     6    0   1   8  78   3   7  307      17     4   48
# 75%      1  20     6    0   1   8  86   4   8  307      17     5   50
# max      3  95    20    1   1   9  94   9  24  666      20     7   50

# %%
boston.describe().map(lambda x: f"{x:.0f}")
# Out:
#       crim   zn indus chas  nox   rm  age  dis  rad  tax ptratio lstat medv
# count  506  506   506  506  506  506  506  506  506  506     506   506  506
# mean     4   11    11    0    1    6   69    4   10  408      18    13   23
# std      9   23     7    0    0    1   28    2    9  169       2     7    9
# min      0    0     0    0    0    4    3    1    1  187      13     2    5
# 25%      0    0     5    0    0    6   45    2    4  279      17     7   17
# 50%      0    0    10    0    1    6   78    3    5  330      19    11   21
# 75%      4   12    18    0    1    7   94    5   24  666      20    17   25
# max     89  100    28    1    1    9  100   12   24  711      22    38   50
